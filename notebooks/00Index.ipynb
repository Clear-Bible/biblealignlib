# %% [markdown]
# # Alignment Data Notebooks
#
# ## Validating Data
#
# * [Validating Token TSVs](10ValidatingTokenTSVs.ipynb)
# * [Comparing Token Sequences](11ComparingTokenSequences.ipynb)
#
# ## Working With Automatic Aligners
#
# * [Automatic Aligners](30AutoAligners.ipynb)
# * [Scoring Alignment Data](31ScoringAlignmentData.ipynb)
# * [Generating Pharaoh Data (for James Cuenod)](37GeneratingPharaohData.ipynb)
#
# ## Reading Legacy Grape City Data
#
# Several sets of alignment data were created by Grape City, a predecessor of Clear. The sources live in the internal `grapecity-alignments` repo, in a JSON format that combines sources, targets, and alignments.
#
# * [Reading Grape City Data](40GrapeCity.ipynb)
